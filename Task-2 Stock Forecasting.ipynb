# %% [markdown]
# # LGM VIRTUAL INTERNSHIP
# ## DATA ANALYTICS

# %% [markdown]
# ## TASK-2 Stock Market Prediction And Forecasting Using Stacked LSTM
# ### Author - Aditya Naranje

# %% [markdown]
# ### Importing required libraries and dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
from sklearn.metrics import mean_squared_error
warnings.filterwarnings(action="ignore")
plt.style.use(["seaborn-bright","dark_background"])

# %%
data = pd.read_csv("Stock_data.csv")
data.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
data["Date"] = pd.to_datetime(data["Date"])
data = data.sort_values(by="Date")

# %%
data.index = data["Date"]

# %%
data.head()
# Out:
#                  Date   Open    High     Low    Last   Close  \
# Date
# 2010-07-21 2010-07-21  122.1  123.00  121.05  121.10  121.55
# 2010-07-22 2010-07-22  120.3  122.00  120.25  120.75  120.90
# 2010-07-23 2010-07-23  121.8  121.95  120.25  120.35  120.65
# 2010-07-26 2010-07-26  120.1  121.00  117.10  117.10  117.60
# 2010-07-27 2010-07-27  117.6  119.50  112.00  118.80  118.65
#
#             Total Trade Quantity  Turnover (Lacs)
# Date
# 2010-07-21                658666           803.56
# 2010-07-22                293312           355.17
# 2010-07-23                281312           340.31
# 2010-07-26                658440           780.01
# 2010-07-27                586100           694.98

# %%
train_size = len(data[:'2017'])

# %%
df = data["Close"].reset_index()
df.drop(columns=["Date"],inplace=True)
df.head()
# Out:
#     Close
# 0  121.55
# 1  120.90
# 2  120.65
# 3  117.60
# 4  118.65

# %%
plt.figure(figsize=(20,6))
plt.plot(data['Close'][:'2017'],color="y")
plt.plot(data['Close']['2018':],color="r")
plt.title("Close Price History",fontsize=20)
plt.legend(['Till 2017','After 2017'])
plt.show()

# %% [markdown]
# ### Scaling Data

# %%
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler(feature_range=(0,1))
df = scale.fit_transform(np.array(df).reshape(-1,1))

# %%
test_size = len(df)-train_size
train_data , test_data = df[0:train_size,:],df[train_size:len(df),:1]

# %%
train_data.shape, test_data.shape, df.shape
# Out:
# ((1850, 1), (185, 1), (2035, 1))

# %% [markdown]
# ### Creating training and test set

# %%
def create_data(lower,upper):
    X = []
    y = []
    time_step = 80
    for i in range(lower,upper):
        X.append(df[i-time_step:i,0])
        y.append(df[i,0])
    X, y = np.array(X), np.array(y)
    X = np.reshape(X, (X.shape[0],X.shape[1],1))
    return X,y

# %%
X_train, y_train = create_data(80,train_size)

# %%
X_test, y_test = create_data(1850,len(df))

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1770, 80, 1), (1770,), (185, 80, 1), (185,))

# %%
### LSTM Model training

# %%
from tensorflow import keras
from keras import models
from tensorflow.keras.layers import Dense, Dropout, LSTM

# %%
model = models.Sequential()
model.add(LSTM(100, return_sequences=True,input_shape=(80,1)))
model.add(Dropout(0.5))
model.add(LSTM(50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50))
model.add(Dense(1))

# %%
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 80, 100)           40800
# _________________________________________________________________
# dropout (Dropout)            (None, 80, 100)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 80, 50)            30200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 80, 50)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 91,251
# Trainable params: 91,251
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=50,batch_size=80,verbose=1)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 13s 273ms/step - loss: 0.0097 - val_loss: 0.0057
# Epoch 2/50
# 23/23 [==============================] - 5s 200ms/step - loss: 0.0015 - val_loss: 0.0088
# Epoch 3/50
# 23/23 [==============================] - 4s 192ms/step - loss: 0.0012 - val_loss: 0.0069
# Epoch 4/50
# 23/23 [==============================] - 4s 192ms/step - loss: 0.0012 - val_loss: 0.0192
# Epoch 5/50
# 23/23 [==============================] - 4s 190ms/step - loss: 5.7332e-04 - val_loss: 0.0027
# Epoch 33/50
# 23/23 [==============================] - 4s 187ms/step - loss: 5.4818e-04 - val_loss: 0.0032
# Epoch 34/50
# 23/23 [==============================] - 4s 190ms/step - loss: 5.1985e-04 - val_loss: 0.0016
# Epoch 35/50
# 23/23 [==============================] - 4s 187ms/step - loss: 5.1162e-04 - val_loss: 0.0015
# Epoch 36/50
# 23/23 [==============================] - 4s 190ms/step - loss: 5.3637e-04 - val_loss: 0.0036
# Epoch 37/50
# 23/23 [==============================] - 4s 191ms/step - loss: 5.7499e-04 - val_loss: 0.0031
# Epoch 38/50
# 23/23 [==============================] - 4s 192ms/step - loss: 5.1666e-04 - val_loss: 0.0016
# Epoch 39/50
# 23/23 [==============================] - 4s 195ms/step - loss: 5.1495e-04 - val_loss: 0.0014
# Epoch 40/50
# 23/23 [==============================] - 4s 186ms/step - loss: 5.0682e-04 - val_loss: 0.0034
# Epoch 41/50
# 23/23 [==============================] - 4s 192ms/step - loss: 5.6242e-04 - val_loss: 0.0038
# Epoch 42/50
# 23/23 [==============================] - 4s 190ms/step - loss: 4.7643e-04 - val_loss: 0.0051
# Epoch 43/50
# 23/23 [==============================] - 5s 210ms/step - loss: 5.0273e-04 - val_loss: 0.0052
# Epoch 44/50
# 23/23 [==============================] - 4s 191ms/step - loss: 5.1841e-04 - val_loss: 0.0049
# Epoch 45/50
# 23/23 [==============================] - 4s 190ms/step - loss: 5.1795e-04 - val_loss: 0.0020
# Epoch 46/50
# 23/23 [==============================] - 4s 193ms/step - loss: 5.1797e-04 - val_loss: 0.0022
# Epoch 47/50
# 23/23 [==============================] - 4s 188ms/step - loss: 4.7675e-04 - val_loss: 0.0021
# Epoch 48/50
# 23/23 [==============================] - 4s 194ms/step - loss: 4.8761e-04 - val_loss: 0.0019
# Epoch 49/50
# 23/23 [==============================] - 4s 190ms/step - loss: 4.5264e-04 - val_loss: 0.0028
# Epoch 50/50
# 23/23 [==============================] - 5s 196ms/step - loss: 4.4128e-04 - val_loss: 0.0016

# %%
pd.DataFrame(hist.history).plot(figsize=(15,5))
plt.grid(False)
plt.show()

# %%
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

# %%
train_pred = scale.inverse_transform(train_pred)
test_pred = scale.inverse_transform(test_pred)

# %%
print(f'Training error : {np.sqrt(mean_squared_error(y_train,train_pred))}')
# Out:
# Training error : 141.92350804876358

# %%
print(f'Testing error : {np.sqrt(mean_squared_error(y_test,test_pred))}')
# Out:
# Testing error : 270.8095456335796

# %%
df1 = pd.DataFrame(data['Close']).iloc[80:,:]

# %%
predicted = []
predicted.extend(train_pred)
predicted.extend(test_pred)

# %%
df1['Predicted'] = predicted

# %%
plt.figure(figsize=(20,7))
plt.plot(df1['Close'],color='r')
plt.plot(df1['Predicted'].iloc[:train_size-80],color = 'lime')
plt.plot(df1['Predicted'].iloc[train_size-80:],color = 'b')
plt.legend([' Actual',' Train Predicted',' Test Predicted'],loc="upper left")
plt.title('Actual vs Predicted',fontsize=20)
plt.show()
